# %%
import pandas as pd

# %%
news_df = pd.read_csv("../news_reuters.txt")

# %%
news_df.head()
# Out:
#    AA  Alcoa Corporation  20110707  \
# 0  AA  Alcoa Corporation  20110708
# 1  AA  Alcoa Corporation  20110708
# 2  AA  Alcoa Corporation  20110708
# 3  AA  Alcoa Corporation  20110708
# 4  AA  Alcoa Corporation  20110708
#
#    Alcoa profit seen higher on aluminum price surge   \
# 0      Global markets weekahead: Lacking conviction
# 1  Jobs halt Wall Street rally  investors eye ear...
# 2     REFILE-TABLE-Australia's top carbon polluters
# 3  US STOCKS-Jobs data hits stocks  but earnings ...
# 4  US STOCKS-Jobs halt Wall St rally  investors e...
#
#    * Analysts expect profit of 34 cts/shr vs year-ago 13 cts  topStory
# 0  LONDON Investors are unlikely to gain strong c...            normal
# 1  NEW YORK Stocks fell on Friday as a weak jobs ...          topStory
# 2   CANBERRA  July 8 Following is a list of Austr...            normal
# 3   * Google slumps on downgrade  one of Nasdaq's...            normal
# 4   * Dow off 0.5 pct  S&P down 0.7 pct  Nasdaq o...            normal

# %%
news_df.tail()
# Out:
#           AA                       Alcoa Corporation  20110707  \
# 215282  ZOES                   Zoe&#39;s Kitchen Inc  20140411
# 215283  ZOES                   Zoe&#39;s Kitchen Inc  20140411
# 215284    ZX  China Zenix Auto International Limited  20170217
# 215285  ZYNE             Zynerba Pharmaceuticals Inc  20170118
# 215286  ZYNE             Zynerba Pharmaceuticals Inc  20170118
#
#         Alcoa profit seen higher on aluminum price surge   \
# 215282  Zoe's Kitchen shares jump more than 70 pct in ...
# 215283  Zoe's Kitchen shares jump more than 70 percent...
# 215284  BRIEF-China Zenix Auto International announces...
# 215285  BRIEF-Zynerba Pharmaceuticals announces propos...
# 215286  BRIEF-Zynerba Pharmaceuticals says estimates t...
#
#         * Analysts expect profit of 34 cts/shr vs year-ago 13 cts  topStory
# 215282  April 11 Shares of Zoe's Kitchen Inc  rose as ...            normal
# 215283  Shares of Zoe's Kitchen Inc   a casual dining ...          topStory
# ...

# %%
news_df.head(100)
# Out:
#     AA  Alcoa Corporation  20110707  \
# 0   AA  Alcoa Corporation  20110708
# 1   AA  Alcoa Corporation  20110708
# 2   AA  Alcoa Corporation  20110708
# 3   AA  Alcoa Corporation  20110708
# 4   AA  Alcoa Corporation  20110708
# ..  ..                ...       ...
# 95  AA  Alcoa Corporation  20120108
# 96  AA  Alcoa Corporation  20120109
# 97  AA  Alcoa Corporation  20120109
# 98  AA  Alcoa Corporation  20120110
# 99  AA  Alcoa Corporation  20120110
#
#     Alcoa profit seen higher on aluminum price surge   \
# 0       Global markets weekahead: Lacking conviction
# 1   Jobs halt Wall Street rally  investors eye ear...
# 2      REFILE-TABLE-Australia's top carbon polluters
# 3   US STOCKS-Jobs data hits stocks  but earnings ...
# 4   US STOCKS-Jobs halt Wall St rally  investors e...
# ..                                                ...
# 95  Alcoa shares could rise 30 percent in 2012: re...
# 96             Alcoa gives positive aluminum outlook
# ...

# %%
news_df.head(1000)
# Out:
#       AA            Alcoa Corporation  20110707  \
# 0     AA            Alcoa Corporation  20110708
# 1     AA            Alcoa Corporation  20110708
# 2     AA            Alcoa Corporation  20110708
# 3     AA            Alcoa Corporation  20110708
# 4     AA            Alcoa Corporation  20110708
# ..   ...                          ...       ...
# 995  AAL  American Airlines Group Inc  20160512
# 996  AAL  American Airlines Group Inc  20160512
# 997  AAL  American Airlines Group Inc  20160517
# 998  AAL  American Airlines Group Inc  20160606
# 999  AAL  American Airlines Group Inc  20160609
#
#      Alcoa profit seen higher on aluminum price surge   \
# 0        Global markets weekahead: Lacking conviction
# 1    Jobs halt Wall Street rally  investors eye ear...
# 2       REFILE-TABLE-Australia's top carbon polluters
# 3    US STOCKS-Jobs data hits stocks  but earnings ...
# 4    US STOCKS-Jobs halt Wall St rally  investors e...
# ...

# %%
news_df["Alcoa profit seen higher on aluminum price surge"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\anish\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Alcoa profit seen higher on aluminum price surge'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
